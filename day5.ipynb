# %% [markdown]
# comparison operators/relational operators

# %%
 t = 6
 s = 5

# %%
print(t > s);
# Out:
# True

# %%
t = 5
s= 5

# %%
print(t == s);
# Out:
# True

# %% [markdown]
# # Conditonal statements(  if  )  (  if else  ) (  nestd if   )

# %%
a = 20
b = 209

if b > a:
    print("he will get admm in iit");
# Out:
# he will get admm in iit

# %%
x = 5
r = x % 2 
if r == 0:
    print("number is even");
else:
    print("number is odd");
# Out:
# number is odd

# %%
age = 19
is_student = True

if age < 18:
    if is_student:

        print("50% student discount")
    else:
        print("25% child discount")
else:
    print("no discount")
# Out:
# no discount

# %%
a = "i love "
b = "python"
print(a + " " + b);
# Out:
# i love  python
